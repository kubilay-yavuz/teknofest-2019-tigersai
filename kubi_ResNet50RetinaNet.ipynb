# %% [markdown]
# ## Load necessary modules

# %%
import os
# os.chdir("drive/My Drive/colab_datas/teknofest/keras-retinanet")

# %%
# !pip install keras_resnet
# Out:
# Requirement already satisfied: keras_resnet in c:\users\mbura\appdata\roaming\python\python36\site-packages (0.1.0)
# Requirement already satisfied: keras in c:\users\mbura\appdata\local\programs\python\python36\lib\site-packages (from keras_resnet) (2.2.4)
# Requirement already satisfied: keras-applications>=1.0.6 in c:\users\mbura\appdata\local\programs\python\python36\lib\site-packages (from keras->keras_resnet) (1.0.7)
# Requirement already satisfied: scipy>=0.14 in c:\users\mbura\appdata\local\programs\python\python36\lib\site-packages (from keras->keras_resnet) (1.2.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in c:\users\mbura\appdata\local\programs\python\python36\lib\site-packages (from keras->keras_resnet) (1.0.9)
# Requirement already satisfied: pyyaml in c:\users\mbura\appdata\local\programs\python\python36\lib\site-packages (from keras->keras_resnet) (3.13)
# Requirement already satisfied: h5py in c:\users\mbura\appdata\local\programs\python\python36\lib\site-packages (from keras->keras_resnet) (2.9.0)
# Requirement already satisfied: numpy>=1.9.1 in c:\users\mbura\appdata\local\programs\python\python36\lib\site-packages (from keras->keras_resnet) (1.16.4)
# Requirement already satisfied: six>=1.9.0 in c:\users\mbura\appdata\local\programs\python\python36\lib\site-packages (from keras->keras_resnet) (1.10.0)
# WARNING: You are using pip version 19.2.2, however version 19.2.3 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
# show images inline
# %matplotlib inline

# automatically reload modules when they have changed
# %load_ext autoreload
# %autoreload 2

# import keras
import keras

# import keras_retinanet
from keras_retinanet import models
from keras_retinanet.utils.image import read_image_bgr, preprocess_image, resize_image
from keras_retinanet.utils.visualization import draw_box, draw_caption
from keras_retinanet.utils.colors import label_color

# import miscellaneous modules
import matplotlib.pyplot as plt
import cv2
import numpy as np
import time
import glob
import pandas as pd
# set tf backend to allow memory to grow, instead of claiming everything
import tensorflow as tf
from tqdm import tqdm_notebook as tqdm

def get_session():
    config = tf.ConfigProto()
    config.gpu_options.allow_growth = True
    return tf.Session(config=config)

# use this environment flag to change which GPU to use
#os.environ["CUDA_VISIBLE_DEVICES"] = "1"

# set the modified tf session as backend in keras
keras.backend.tensorflow_backend.set_session(get_session())
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# import json
# with open("photos/data.json","r") as json_file:
#     data=json.load(json_file)
# data_df=pd.DataFrame(data)
# down_data={}
# for row in tqdm(data_df.values):
#     path_to_image="photos/test_images/"+str(row[0])+".jpg"
#     down_data[path_to_image]=row[1]
# down_data
# import requests
# for key in tqdm(down_data.keys()):
#     path_to_image=key
#     r = requests.get(down_data[key])
#     open(path_to_image, 'wb').write(r.content)

# %%
#import requests
#not_downloaded=[]
#for row in tqdm(data.values):
#    path_to_image="photos/test_images/"+str(row[0])+".jpg"
#    Picture_request = requests.get(row[1])
#    if Picture_request.status_code == 200:
#        with open(path_to_image, 'wb') as f:
#            f.write(Picture_request.content)
#    else:
#        not_downloaded.append(row)

# %%
val_set=glob.glob("photos/test_images/*")
len(val_set) #should equal to 4349

# %%
# val_set=glob.glob("photos/t3_new_data/*/*")

# %% [markdown]
# ## Random 50 prediction

# %%
labels_to_names = {0: 'yaya', 1: 'arac'}
# val_sample=np.random.choice(val_set,150)

# %%
# # !python keras_retinanet/bin/convert_model.py ./snapshots/resnet152_csv_07.h5 ./snapshots/infer_model.h5
# # model = models.load_model("./snapshots/infer_model.h5", backbone_name='resnet152')
# # resnet152_images=[]
# # for i in val_sample:# load image
# #     image = read_image_bgr(i)

# #     # copy to draw on
# #     sha=image.shape
# #     draw = image.copy()
# #     draw = cv2.cvtColor(draw, cv2.COLOR_BGR2RGB)

# #     # preprocess image for network
# #     image = preprocess_image(image)
# #     image, scale = resize_image(image)

# #     # process image
# #     start = time.time()
# #     boxes, scores, labels = model.predict_on_batch(np.expand_dims(image, axis=0))
# #     print("processing time: ", time.time() - start)
# #     print(i)
# #     # correct for image scale
# #     boxes /= scale
# #     #for j in val_csv.loc[val_csv[0]==i].values:
# #     #    draw_box(draw, j[1:5], color=[0,255,0])
# #     #    draw_caption(draw, (j[1],j[4]+30), j[5])
# #     # visualize detections
# #     for box, score, label in zip(boxes[0], scores[0], labels[0]):
# #         # scores are sorted so we can break
# #         if score < 0.5:
# #             break
# #         color = label_color(label)

# #         b = box.astype(int)
# #         draw_box(draw, b, color=color)
        
# #         caption = "{} {:.3f}".format(labels_to_names[label], score)
# #         draw_caption(draw, b, caption)
# #     font = cv2.FONT_HERSHEY_SIMPLEX
# #     cv2.putText(draw,'resnet152',(10,500), font, 4,(255,255,255),2,cv2.LINE_AA)
# #     resnet152_images.append(draw)
# # !python keras_retinanet/bin/convert_model.py ./snapshots/resnet101_csv_06.h5 ./snapshots/infer_model.h5
# # model = models.load_model("./snapshots/infer_model.h5", backbone_name='resnet101')
# # resnet101_images=[]
# # for i in val_sample:# load image
# #     image = read_image_bgr(i)

# #     # copy to draw on
# #     sha=image.shape
# #     draw = image.copy()
# #     draw = cv2.cvtColor(draw, cv2.COLOR_BGR2RGB)

# #     # preprocess image for network
# #     image = preprocess_image(image)
# #     image, scale = resize_image(image)

# #     # process image
# #     start = time.time()
# #     boxes, scores, labels = model.predict_on_batch(np.expand_dims(image, axis=0))
# #     print("processing time: ", time.time() - start)
# #     print(i)
# #     # correct for image scale
# #     boxes /= scale
# #     #for j in val_csv.loc[val_csv[0]==i].values:
# #     #    draw_box(draw, j[1:5], color=[0,255,0])
# #     #    draw_caption(draw, (j[1],j[4]+30), j[5])
# #     # visualize detections
# #     for box, score, label in zip(boxes[0], scores[0], labels[0]):
# #         # scores are sorted so we can break
# #         if score < 0.5:
# #             break
# #         color = label_color(label)

# #         b = box.astype(int)
# #         draw_box(draw, b, color=color)
        
# #         caption = "{} {:.3f}".format(labels_to_names[label], score)
# #         draw_caption(draw, b, caption)
# #     font = cv2.FONT_HERSHEY_SIMPLEX
# #     cv2.putText(draw,'resnet101',(10,500), font, 4,(255,255,255),2,cv2.LINE_AA)
# #     resnet101_images.append(draw)

# # Epoch 00001: saving model to ./snapshots/resnet50_csv_01.h5

# !python keras_retinanet/bin/convert_model.py ./snapshots_woconfig/resnet50_csv_13.h5 ./snapshots/infer_model.h5
# model = models.load_model("./snapshots/infer_model.h5", backbone_name='resnet50')
# resnet50_images=[]
# for i in val_sample:# load image
#     image = read_image_bgr(i)

#     # copy to draw on
#     sha=image.shape
#     draw = image.copy()
#     draw = cv2.cvtColor(draw, cv2.COLOR_BGR2RGB)

#     # preprocess image for network
#     image = preprocess_image(image)
#     image, scale = resize_image(image,max_side=3000)

#     # process image
#     start = time.time()
#     boxes, scores, labels = model.predict_on_batch(np.expand_dims(image, axis=0))
#     print("processing time: ", time.time() - start)
#     print(i)
#     # correct for image scale
#     boxes /= scale
#     #for j in val_csv.loc[val_csv[0]==i].values:
#     #    draw_box(draw, j[1:5], color=[0,255,0])
#     #    draw_caption(draw, (j[1],j[4]+30), j[5])
#     # visualize detections
#     for box, score, label in zip(boxes[0], scores[0], labels[0]):
#         # scores are sorted so we can break
#         if score < 0.5:
#             break
#         color = label_color(label)

#         b = box.astype(int)
#         draw_box(draw, b, color=color)
        
#         caption = "{} {:.3f}".format(labels_to_names[label], score)
#         draw_caption(draw, b, caption)
#     # font = cv2.FONT_HERSHEY_SIMPLEX
#     # cv2.putText(draw,'resnet50',(10,500), font, 4,(255,255,255),2,cv2.LINE_AA)
#     resnet50_images.append(draw)
# os.mkdir("son_train_woaug")
# for i in range(len(resnet50_images)):
#     image_=cv2.cvtColor(resnet50_images[i],cv2.COLOR_BGR2RGB)
#     cv2.imwrite("son_train_woaug/{}.jpg".format(i),image_)
#     # plt.figure(figsize=(20, 20))
#     # plt.axis('off')
#     # plt.imshow(image)
#     # plt.show()
#     # plt.pause(0.01)

# %% [markdown]
# ## Predd reeel

# %%
# !python C:/Users/mbura/keras-retinanet/keras_retinanet/bin/convert_model.py ./snapshots/resnet50_csv_14.h5 ./snapshots/resnet50_csv_14_infer.h5

# %%
val_sample=glob.glob("photos/test_images/*")
val_sample
# Out:
# ['photos/test_images\\1.jpg',
#  'photos/test_images\\10.jpg',
#  'photos/test_images\\100.jpg',
#  'photos/test_images\\1000.jpg',
#  'photos/test_images\\1001.jpg',
#  'photos/test_images\\1002.jpg',
#  'photos/test_images\\1003.jpg',
#  'photos/test_images\\1004.jpg',
#  'photos/test_images\\1005.jpg',
#  'photos/test_images\\1006.jpg',
#  'photos/test_images\\1007.jpg',
#  'photos/test_images\\1008.jpg',
#  'photos/test_images\\1009.jpg',
#  'photos/test_images\\101.jpg',
#  'photos/test_images\\1010.jpg',
#  'photos/test_images\\1011.jpg',
#  'photos/test_images\\1012.jpg',
#  'photos/test_images\\1013.jpg',
#  'photos/test_images\\1014.jpg',
#  'photos/test_images\\1015.jpg',
#  'photos/test_images\\1016.jpg',
#  'photos/test_images\\1017.jpg',
#  'photos/test_images\\1018.jpg',
#  'photos/test_images\\1019.jpg',
#  'photos/test_images\\102.jpg',
#  'photos/test_images\\1020.jpg',
#  'photos/test_images\\1021.jpg',
#  'photos/test_images\\1022.jpg',
#  'photos/test_images\\1023.jpg',
#  'photos/test_images\\1024.jpg',
#  'photos/test_images\\1025.jpg',
#  'photos/test_images\\1026.jpg',
#  'photos/test_images\\1027.jpg',
#  'photos/test_images\\1028.jpg',
#  'photos/test_images\\1029.jpg',
#  'photos/test_images\\103.jpg',
#  'photos/test_images\\1030.jpg',
#  'photos/test_images\\1031.jpg',
#  'photos/test_images\\1032.jpg',
#  'photos/test_images\\1033.jpg',
#  'photos/test_images\\1034.jpg',
#  'photos/test_images\\1035.jpg',
#  'photos/test_images\\1036.jpg',
#  'photos/test_images\\1037.jpg',
#  'photos/test_images\\1038.jpg',
#  'photos/test_images\\1039.jpg',
#  'photos/test_images\\104.jpg',
#  'photos/test_images\\1040.jpg',
#  'photos/test_images\\1041.jpg',
#  'photos/test_images\\1042.jpg',
#  'photos/test_images\\1043.jpg',
#  'photos/test_images\\1044.jpg',
#  'photos/test_images\\1045.jpg',
#  'photos/test_images\\1046.jpg',
#  'photos/test_images\\1047.jpg',
#  'photos/test_images\\1048.jpg',
#  'photos/test_images\\1049.jpg',
#  'photos/test_images\\105.jpg',
#  'photos/test_images\\1050.jpg',
#  'photos/test_images\\1051.jpg',
#  'photos/test_images\\1052.jpg',
#  'photos/test_images\\1053.jpg',
#  'photos/test_images\\1054.jpg',
#  'photos/test_images\\1055.jpg',
#  'photos/test_images\\1056.jpg',
#  'photos/test_images\\1057.jpg',
#  'photos/test_images\\1058.jpg',
#  'photos/test_images\\1059.jpg',
#  'photos/test_images\\106.jpg',
#  'photos/test_images\\1060.jpg',
#  'photos/test_images\\1061.jpg',
#  'photos/test_images\\1062.jpg',
#  'photos/test_images\\1063.jpg',
#  'photos/test_images\\1064.jpg',
#  'photos/test_images\\1065.jpg',
#  'photos/test_images\\1066.jpg',
#  'photos/test_images\\1067.jpg',
#  'photos/test_images\\1068.jpg',
#  'photos/test_images\\1069.jpg',
#  'photos/test_images\\107.jpg',
#  'photos/test_images\\1070.jpg',
#  'photos/test_images\\1071.jpg',
#  'photos/test_images\\1072.jpg',
#  'photos/test_images\\1073.jpg',
#  'photos/test_images\\1074.jpg',
#  'photos/test_images\\1075.jpg',
#  'photos/test_images\\1076.jpg',
#  'photos/test_images\\1077.jpg',
#  'photos/test_images\\1078.jpg',
#  'photos/test_images\\1079.jpg',
#  'photos/test_images\\108.jpg',
#  'photos/test_images\\1080.jpg',
#  'photos/test_images\\1081.jpg',
#  'photos/test_images\\1082.jpg',
#  'photos/test_images\\1083.jpg',
#  'photos/test_images\\1084.jpg',
#  'photos/test_images\\1085.jpg',
#  'photos/test_images\\1086.jpg',
#  'photos/test_images\\1087.jpg',
#  'photos/test_images\\1088.jpg',
#  'photos/test_images\\1089.jpg',
#  'photos/test_images\\109.jpg',
#  'photos/test_images\\1090.jpg',
#  'photos/test_images\\1091.jpg',
#  'photos/test_images\\1092.jpg',
#  'photos/test_images\\1093.jpg',
#  'photos/test_images\\1094.jpg',
#  'photos/test_images\\1095.jpg',
#  'photos/test_images\\1096.jpg',
#  'photos/test_images\\1097.jpg',
#  'photos/test_images\\1098.jpg',
#  'photos/test_images\\1099.jpg',
#  'photos/test_images\\11.jpg',
#  'photos/test_images\\110.jpg',
#  'photos/test_images\\1100.jpg',
#  'photos/test_images\\1101.jpg',
#  'photos/test_images\\1102.jpg',
#  'photos/test_images\\1103.jpg',
#  'photos/test_images\\1104.jpg',
#  'photos/test_images\\1105.jpg',
#  'photos/test_images\\1106.jpg',
#  'photos/test_images\\1107.jpg',
#  'photos/test_images\\1108.jpg',
#  'photos/test_images\\1109.jpg',
#  'photos/test_images\\111.jpg',
#  'photos/test_images\\1110.jpg',
#  'photos/test_images\\1111.jpg',
#  'photos/test_images\\1112.jpg',
#  'photos/test_images\\1113.jpg',
#  'photos/test_images\\1114.jpg',
#  'photos/test_images\\1115.jpg',
#  'photos/test_images\\1116.jpg',
#  'photos/test_images\\1117.jpg',
#  'photos/test_images\\1118.jpg',
#  'photos/test_images\\1119.jpg',
#  'photos/test_images\\112.jpg',
#  'photos/test_images\\1120.jpg',
#  'photos/test_images\\1121.jpg',
#  'photos/test_images\\1122.jpg',
#  'photos/test_images\\1123.jpg',
#  'photos/test_images\\1124.jpg',
#  'photos/test_images\\1125.jpg',
#  'photos/test_images\\1126.jpg',
#  'photos/test_images\\1127.jpg',
#  'photos/test_images\\1128.jpg',
#  'photos/test_images\\1129.jpg',
#  'photos/test_images\\113.jpg',
#  'photos/test_images\\1130.jpg',
#  'photos/test_images\\1131.jpg',
#  'photos/test_images\\1132.jpg',
#  'photos/test_images\\1133.jpg',
#  'photos/test_images\\1134.jpg',
#  'photos/test_images\\1135.jpg',
#  'photos/test_images\\1136.jpg',
#  'photos/test_images\\1137.jpg',
#  'photos/test_images\\1138.jpg',
#  'photos/test_images\\1139.jpg',
#  'photos/test_images\\114.jpg',
#  'photos/test_images\\1140.jpg',
#  'photos/test_images\\1141.jpg',
#  'photos/test_images\\1142.jpg',
#  'photos/test_images\\1143.jpg',
#  'photos/test_images\\1144.jpg',
#  'photos/test_images\\1145.jpg',
#  'photos/test_images\\1146.jpg',
#  'photos/test_images\\1147.jpg',
#  'photos/test_images\\1148.jpg',
#  'photos/test_images\\1149.jpg',
#  'photos/test_images\\115.jpg',
#  'photos/test_images\\1150.jpg',
#  'photos/test_images\\1151.jpg',
#  'photos/test_images\\1152.jpg',
#  'photos/test_images\\1153.jpg',
#  'photos/test_images\\1154.jpg',
#  'photos/test_images\\1155.jpg',
#  'photos/test_images\\1156.jpg',
#  'photos/test_images\\1157.jpg',
#  'photos/test_images\\1158.jpg',
#  'photos/test_images\\1159.jpg',
#  'photos/test_images\\116.jpg',
#  'photos/test_images\\1160.jpg',
#  'photos/test_images\\1161.jpg',
#  'photos/test_images\\1162.jpg',
#  'photos/test_images\\1163.jpg',
#  'photos/test_images\\1164.jpg',
#  'photos/test_images\\1165.jpg',
#  'photos/test_images\\1166.jpg',
#  'photos/test_images\\1167.jpg',
#  'photos/test_images\\1168.jpg',
#  'photos/test_images\\1169.jpg',
#  'photos/test_images\\117.jpg',
#  'photos/test_images\\1170.jpg',
#  'photos/test_images\\1171.jpg',
#  'photos/test_images\\1172.jpg',
#  'photos/test_images\\1173.jpg',
#  'photos/test_images\\1174.jpg',
#  'photos/test_images\\1175.jpg',
#  'photos/test_images\\1176.jpg',
#  'photos/test_images\\1177.jpg',
#  'photos/test_images\\1178.jpg',
#  'photos/test_images\\1179.jpg',
#  'photos/test_images\\118.jpg',
#  'photos/test_images\\1180.jpg',
#  'photos/test_images\\1181.jpg',
#  'photos/test_images\\1182.jpg',
#  'photos/test_images\\1183.jpg',
#  'photos/test_images\\1184.jpg',
#  'photos/test_images\\1185.jpg',
#  'photos/test_images\\1186.jpg',
#  'photos/test_images\\1187.jpg',
#  'photos/test_images\\1188.jpg',
#  'photos/test_images\\1189.jpg',
#  'photos/test_images\\119.jpg',
#  'photos/test_images\\1190.jpg',
#  'photos/test_images\\1191.jpg',
#  'photos/test_images\\1192.jpg',
#  'photos/test_images\\1193.jpg',
#  'photos/test_images\\1194.jpg',
#  'photos/test_images\\1195.jpg',
#  'photos/test_images\\1196.jpg',
#  'photos/test_images\\1197.jpg',
#  'photos/test_images\\1198.jpg',
#  'photos/test_images\\1199.jpg',
#  'photos/test_images\\12.jpg',
#  'photos/test_images\\120.jpg',
#  'photos/test_images\\1200.jpg',
#  'photos/test_images\\1201.jpg',
#  'photos/test_images\\1202.jpg',
#  'photos/test_images\\1203.jpg',
#  'photos/test_images\\1204.jpg',
#  'photos/test_images\\1205.jpg',
#  'photos/test_images\\1206.jpg',
#  'photos/test_images\\1207.jpg',
#  'photos/test_images\\1208.jpg',
#  'photos/test_images\\1209.jpg',
#  'photos/test_images\\121.jpg',
#  'photos/test_images\\1210.jpg',
#  'photos/test_images\\1211.jpg',
#  'photos/test_images\\1212.jpg',
#  'photos/test_images\\1213.jpg',
#  'photos/test_images\\1214.jpg',
#  'photos/test_images\\1215.jpg',
#  'photos/test_images\\1216.jpg',
#  'photos/test_images\\1217.jpg',
#  'photos/test_images\\1218.jpg',
#  'photos/test_images\\1219.jpg',
#  'photos/test_images\\122.jpg',
#  'photos/test_images\\1220.jpg',
#  'photos/test_images\\1221.jpg',
#  'photos/test_images\\1222.jpg',
#  'photos/test_images\\1223.jpg',
#  'photos/test_images\\1224.jpg',
#  'photos/test_images\\1225.jpg',
#  'photos/test_images\\1226.jpg',
#  'photos/test_images\\1227.jpg',
#  'photos/test_images\\1228.jpg',
#  'photos/test_images\\1229.jpg',
#  'photos/test_images\\123.jpg',
#  'photos/test_images\\1230.jpg',
#  'photos/test_images\\1231.jpg',
#  'photos/test_images\\1232.jpg',
#  'photos/test_images\\1233.jpg',
#  'photos/test_images\\1234.jpg',
#  'photos/test_images\\1235.jpg',
#  'photos/test_images\\1236.jpg',
#  'photos/test_images\\1237.jpg',
#  'photos/test_images\\1238.jpg',
#  'photos/test_images\\1239.jpg',
#  'photos/test_images\\124.jpg',
#  'photos/test_images\\1240.jpg',
#  'photos/test_images\\1241.jpg',
#  'photos/test_images\\1242.jpg',
#  'photos/test_images\\1243.jpg',
#  'photos/test_images\\1244.jpg',
#  'photos/test_images\\1245.jpg',
#  'photos/test_images\\1246.jpg',
#  'photos/test_images\\1247.jpg',
#  'photos/test_images\\1248.jpg',
#  'photos/test_images\\1249.jpg',
#  'photos/test_images\\125.jpg',
#  'photos/test_images\\1250.jpg',
#  'photos/test_images\\1251.jpg',
#  'photos/test_images\\1252.jpg',
#  'photos/test_images\\1253.jpg',
#  'photos/test_images\\1254.jpg',
#  'photos/test_images\\1255.jpg',
#  'photos/test_images\\1256.jpg',
#  'photos/test_images\\1257.jpg',
#  'photos/test_images\\1258.jpg',
#  'photos/test_images\\1259.jpg',
#  'photos/test_images\\126.jpg',
#  'photos/test_images\\1260.jpg',
#  'photos/test_images\\1261.jpg',
#  'photos/test_images\\1262.jpg',
#  'photos/test_images\\1263.jpg',
#  'photos/test_images\\1264.jpg',
#  'photos/test_images\\1265.jpg',
#  'photos/test_images\\1266.jpg',
#  'photos/test_images\\1267.jpg',
#  'photos/test_images\\1268.jpg',
#  'photos/test_images\\1269.jpg',
#  'photos/test_images\\127.jpg',
#  'photos/test_images\\1270.jpg',
#  'photos/test_images\\1271.jpg',
#  'photos/test_images\\1272.jpg',
#  'photos/test_images\\1273.jpg',
#  'photos/test_images\\1274.jpg',
#  'photos/test_images\\1275.jpg',
#  'photos/test_images\\1276.jpg',
#  'photos/test_images\\1277.jpg',
#  'photos/test_images\\1278.jpg',
#  'photos/test_images\\1279.jpg',
#  'photos/test_images\\128.jpg',
#  'photos/test_images\\1280.jpg',
#  'photos/test_images\\1281.jpg',
#  'photos/test_images\\1282.jpg',
#  'photos/test_images\\1283.jpg',
#  'photos/test_images\\1284.jpg',
#  'photos/test_images\\1285.jpg',
#  'photos/test_images\\1286.jpg',
#  'photos/test_images\\1287.jpg',
#  'photos/test_images\\1288.jpg',
#  'photos/test_images\\1289.jpg',
#  'photos/test_images\\129.jpg',
#  'photos/test_images\\1290.jpg',
#  'photos/test_images\\1291.jpg',
#  'photos/test_images\\1292.jpg',
#  'photos/test_images\\1293.jpg',
#  'photos/test_images\\1294.jpg',
#  'photos/test_images\\1295.jpg',
#  'photos/test_images\\1296.jpg',
#  'photos/test_images\\1297.jpg',
#  'photos/test_images\\1298.jpg',
#  'photos/test_images\\1299.jpg',
#  'photos/test_images\\13.jpg',
#  'photos/test_images\\130.jpg',
#  'photos/test_images\\1300.jpg',
#  'photos/test_images\\1301.jpg',
#  'photos/test_images\\1302.jpg',
#  'photos/test_images\\1303.jpg',
#  'photos/test_images\\1304.jpg',
#  'photos/test_images\\1305.jpg',
#  'photos/test_images\\1306.jpg',
#  'photos/test_images\\1307.jpg',
#  'photos/test_images\\1308.jpg',
#  'photos/test_images\\1309.jpg',
#  'photos/test_images\\131.jpg',
#  'photos/test_images\\1310.jpg',
#  'photos/test_images\\1311.jpg',
#  'photos/test_images\\1312.jpg',
#  'photos/test_images\\1313.jpg',
#  'photos/test_images\\1314.jpg',
#  'photos/test_images\\1315.jpg',
#  'photos/test_images\\1316.jpg',
#  'photos/test_images\\1317.jpg',
#  'photos/test_images\\1318.jpg',
#  'photos/test_images\\1319.jpg',
#  'photos/test_images\\132.jpg',
#  'photos/test_images\\1320.jpg',
#  'photos/test_images\\1321.jpg',
#  'photos/test_images\\1322.jpg',
#  'photos/test_images\\1323.jpg',
#  'photos/test_images\\1324.jpg',
#  'photos/test_images\\1325.jpg',
#  'photos/test_images\\1326.jpg',
#  'photos/test_images\\1327.jpg',
#  'photos/test_images\\1328.jpg',
#  'photos/test_images\\1329.jpg',
#  'photos/test_images\\133.jpg',
#  'photos/test_images\\1330.jpg',
#  'photos/test_images\\1331.jpg',
#  'photos/test_images\\1332.jpg',
#  'photos/test_images\\1333.jpg',
#  'photos/test_images\\1334.jpg',
#  'photos/test_images\\1335.jpg',
#  'photos/test_images\\1336.jpg',
#  'photos/test_images\\1337.jpg',
#  'photos/test_images\\1338.jpg',
#  'photos/test_images\\1339.jpg',
#  'photos/test_images\\134.jpg',
#  'photos/test_images\\1340.jpg',
#  'photos/test_images\\1341.jpg',
#  'photos/test_images\\1342.jpg',
#  'photos/test_images\\1343.jpg',
#  'photos/test_images\\1344.jpg',
#  'photos/test_images\\1345.jpg',
#  'photos/test_images\\1346.jpg',
#  'photos/test_images\\1347.jpg',
#  'photos/test_images\\1348.jpg',
#  'photos/test_images\\1349.jpg',
#  'photos/test_images\\135.jpg',
#  'photos/test_images\\1350.jpg',
#  'photos/test_images\\1351.jpg',
#  'photos/test_images\\1352.jpg',
#  'photos/test_images\\1353.jpg',
#  'photos/test_images\\1354.jpg',
#  'photos/test_images\\1355.jpg',
#  'photos/test_images\\1356.jpg',
#  'photos/test_images\\1357.jpg',
#  'photos/test_images\\1358.jpg',
#  'photos/test_images\\1359.jpg',
#  'photos/test_images\\136.jpg',
#  'photos/test_images\\1360.jpg',
#  'photos/test_images\\1361.jpg',
#  'photos/test_images\\1362.jpg',
#  'photos/test_images\\1363.jpg',
#  'photos/test_images\\1364.jpg',
#  'photos/test_images\\1365.jpg',
#  'photos/test_images\\1366.jpg',
#  'photos/test_images\\1367.jpg',
#  'photos/test_images\\1368.jpg',
#  'photos/test_images\\1369.jpg',
#  'photos/test_images\\137.jpg',
#  'photos/test_images\\1370.jpg',
#  'photos/test_images\\1371.jpg',
#  'photos/test_images\\1372.jpg',
#  'photos/test_images\\1373.jpg',
#  'photos/test_images\\1374.jpg',
#  'photos/test_images\\1375.jpg',
#  'photos/test_images\\1376.jpg',
#  'photos/test_images\\1377.jpg',
#  'photos/test_images\\1378.jpg',
#  'photos/test_images\\1379.jpg',
#  'photos/test_images\\138.jpg',
#  'photos/test_images\\1380.jpg',
#  'photos/test_images\\1381.jpg',
#  'photos/test_images\\1382.jpg',
#  'photos/test_images\\1383.jpg',
#  'photos/test_images\\1384.jpg',
#  'photos/test_images\\1385.jpg',
#  'photos/test_images\\1386.jpg',
#  'photos/test_images\\1387.jpg',
#  'photos/test_images\\1388.jpg',
#  'photos/test_images\\1389.jpg',
#  'photos/test_images\\139.jpg',
#  'photos/test_images\\1390.jpg',
#  'photos/test_images\\1391.jpg',
#  'photos/test_images\\1392.jpg',
#  'photos/test_images\\1393.jpg',
#  'photos/test_images\\1394.jpg',
#  'photos/test_images\\1395.jpg',
#  'photos/test_images\\1396.jpg',
#  'photos/test_images\\1397.jpg',
#  'photos/test_images\\1398.jpg',
#  'photos/test_images\\1399.jpg',
#  'photos/test_images\\14.jpg',
#  'photos/test_images\\140.jpg',
#  'photos/test_images\\1400.jpg',
#  'photos/test_images\\1401.jpg',
#  'photos/test_images\\1402.jpg',
#  'photos/test_images\\1403.jpg',
#  'photos/test_images\\1404.jpg',
#  'photos/test_images\\1405.jpg',
#  'photos/test_images\\1406.jpg',
#  'photos/test_images\\1407.jpg',
#  'photos/test_images\\1408.jpg',
#  'photos/test_images\\1409.jpg',
#  'photos/test_images\\141.jpg',
#  'photos/test_images\\1410.jpg',
#  'photos/test_images\\1411.jpg',
#  'photos/test_images\\1412.jpg',
#  'photos/test_images\\1413.jpg',
#  'photos/test_images\\1414.jpg',
#  'photos/test_images\\1415.jpg',
#  'photos/test_images\\1416.jpg',
#  'photos/test_images\\1417.jpg',
#  'photos/test_images\\1418.jpg',
#  'photos/test_images\\1419.jpg',
#  'photos/test_images\\142.jpg',
#  'photos/test_images\\1420.jpg',
#  'photos/test_images\\1421.jpg',
#  'photos/test_images\\1422.jpg',
#  'photos/test_images\\1423.jpg',
#  'photos/test_images\\1424.jpg',
#  'photos/test_images\\1425.jpg',
#  'photos/test_images\\1426.jpg',
#  'photos/test_images\\1427.jpg',
#  'photos/test_images\\1428.jpg',
#  'photos/test_images\\1429.jpg',
#  'photos/test_images\\143.jpg',
#  'photos/test_images\\1430.jpg',
#  'photos/test_images\\1431.jpg',
#  'photos/test_images\\1432.jpg',
#  'photos/test_images\\1433.jpg',
#  'photos/test_images\\1434.jpg',
#  'photos/test_images\\1435.jpg',
#  'photos/test_images\\1436.jpg',
#  'photos/test_images\\1437.jpg',
#  'photos/test_images\\1438.jpg',
#  'photos/test_images\\1439.jpg',
#  'photos/test_images\\144.jpg',
#  'photos/test_images\\1440.jpg',
#  'photos/test_images\\1441.jpg',
#  'photos/test_images\\1442.jpg',
#  'photos/test_images\\1443.jpg',
#  'photos/test_images\\1444.jpg',
#  'photos/test_images\\1445.jpg',
#  'photos/test_images\\1446.jpg',
#  'photos/test_images\\1447.jpg',
#  'photos/test_images\\1448.jpg',
#  'photos/test_images\\1449.jpg',
#  'photos/test_images\\145.jpg',
#  'photos/test_images\\1450.jpg',
#  'photos/test_images\\1451.jpg',
#  'photos/test_images\\1452.jpg',
#  'photos/test_images\\1453.jpg',
#  'photos/test_images\\1454.jpg',
#  'photos/test_images\\1455.jpg',
#  'photos/test_images\\1456.jpg',
#  'photos/test_images\\1457.jpg',
#  'photos/test_images\\1458.jpg',
#  'photos/test_images\\1459.jpg',
#  'photos/test_images\\146.jpg',
#  'photos/test_images\\1460.jpg',
#  'photos/test_images\\1461.jpg',
#  'photos/test_images\\1462.jpg',
#  'photos/test_images\\1463.jpg',
#  'photos/test_images\\1464.jpg',
#  'photos/test_images\\1465.jpg',
#  'photos/test_images\\1466.jpg',
#  'photos/test_images\\1467.jpg',
#  'photos/test_images\\1468.jpg',
#  'photos/test_images\\1469.jpg',
#  'photos/test_images\\147.jpg',
#  'photos/test_images\\1470.jpg',
#  'photos/test_images\\1471.jpg',
#  'photos/test_images\\1472.jpg',
#  'photos/test_images\\1473.jpg',
#  'photos/test_images\\1474.jpg',
#  'photos/test_images\\1475.jpg',
#  'photos/test_images\\1476.jpg',
#  'photos/test_images\\1477.jpg',
#  'photos/test_images\\1478.jpg',
#  'photos/test_images\\1479.jpg',
#  'photos/test_images\\148.jpg',
#  'photos/test_images\\1480.jpg',
#  'photos/test_images\\1481.jpg',
#  'photos/test_images\\1482.jpg',
#  'photos/test_images\\1483.jpg',
#  'photos/test_images\\1484.jpg',
#  'photos/test_images\\1485.jpg',
#  'photos/test_images\\1486.jpg',
#  'photos/test_images\\1487.jpg',
#  'photos/test_images\\1488.jpg',
#  'photos/test_images\\1489.jpg',
#  'photos/test_images\\149.jpg',
#  'photos/test_images\\1490.jpg',
#  'photos/test_images\\1491.jpg',
#  'photos/test_images\\1492.jpg',
#  'photos/test_images\\1493.jpg',
#  'photos/test_images\\1494.jpg',
#  'photos/test_images\\1495.jpg',
#  'photos/test_images\\1496.jpg',
#  'photos/test_images\\1497.jpg',
#  'photos/test_images\\1498.jpg',
#  'photos/test_images\\1499.jpg',
#  'photos/test_images\\15.jpg',
#  'photos/test_images\\150.jpg',
#  'photos/test_images\\1500.jpg',
#  'photos/test_images\\1501.jpg',
#  'photos/test_images\\1502.jpg',
#  'photos/test_images\\1503.jpg',
#  'photos/test_images\\1504.jpg',
#  'photos/test_images\\1505.jpg',
#  'photos/test_images\\1506.jpg',
#  'photos/test_images\\1507.jpg',
#  'photos/test_images\\1508.jpg',
#  'photos/test_images\\1509.jpg',
#  'photos/test_images\\151.jpg',
#  'photos/test_images\\1510.jpg',
#  'photos/test_images\\1511.jpg',
#  'photos/test_images\\1512.jpg',
#  'photos/test_images\\1513.jpg',
#  'photos/test_images\\1514.jpg',
#  'photos/test_images\\1515.jpg',
#  'photos/test_images\\1516.jpg',
#  'photos/test_images\\1517.jpg',
#  'photos/test_images\\1518.jpg',
#  'photos/test_images\\1519.jpg',
#  'photos/test_images\\152.jpg',
#  'photos/test_images\\1520.jpg',
#  'photos/test_images\\1521.jpg',
#  'photos/test_images\\1522.jpg',
#  'photos/test_images\\1523.jpg',
#  'photos/test_images\\1524.jpg',
#  'photos/test_images\\1525.jpg',
#  'photos/test_images\\1526.jpg',
#  'photos/test_images\\1527.jpg',
#  'photos/test_images\\1528.jpg',
#  'photos/test_images\\1529.jpg',
#  'photos/test_images\\153.jpg',
#  'photos/test_images\\1530.jpg',
#  'photos/test_images\\1531.jpg',
#  'photos/test_images\\1532.jpg',
#  'photos/test_images\\1533.jpg',
#  'photos/test_images\\1534.jpg',
#  'photos/test_images\\1535.jpg',
#  'photos/test_images\\1536.jpg',
#  'photos/test_images\\1537.jpg',
#  'photos/test_images\\1538.jpg',
#  'photos/test_images\\1539.jpg',
#  'photos/test_images\\154.jpg',
#  'photos/test_images\\1540.jpg',
#  'photos/test_images\\1541.jpg',
#  'photos/test_images\\1542.jpg',
#  'photos/test_images\\1543.jpg',
#  'photos/test_images\\1544.jpg',
#  'photos/test_images\\1545.jpg',
#  'photos/test_images\\1546.jpg',
#  'photos/test_images\\1547.jpg',
#  'photos/test_images\\1548.jpg',
#  'photos/test_images\\1549.jpg',
#  'photos/test_images\\155.jpg',
#  'photos/test_images\\1550.jpg',
#  'photos/test_images\\1551.jpg',
#  'photos/test_images\\1552.jpg',
#  'photos/test_images\\1553.jpg',
#  'photos/test_images\\1554.jpg',
#  'photos/test_images\\1555.jpg',
#  'photos/test_images\\1556.jpg',
#  'photos/test_images\\1557.jpg',
#  'photos/test_images\\1558.jpg',
#  'photos/test_images\\1559.jpg',
#  'photos/test_images\\156.jpg',
#  'photos/test_images\\1560.jpg',
#  'photos/test_images\\1561.jpg',
#  'photos/test_images\\1562.jpg',
#  'photos/test_images\\1563.jpg',
#  'photos/test_images\\1564.jpg',
#  'photos/test_images\\1565.jpg',
#  'photos/test_images\\1566.jpg',
#  'photos/test_images\\1567.jpg',
#  'photos/test_images\\1568.jpg',
#  'photos/test_images\\1569.jpg',
#  'photos/test_images\\157.jpg',
#  'photos/test_images\\1570.jpg',
#  'photos/test_images\\1571.jpg',
#  'photos/test_images\\1572.jpg',
#  'photos/test_images\\1573.jpg',
#  'photos/test_images\\1574.jpg',
#  'photos/test_images\\1575.jpg',
#  'photos/test_images\\1576.jpg',
#  'photos/test_images\\1577.jpg',
#  'photos/test_images\\1578.jpg',
#  'photos/test_images\\1579.jpg',
#  'photos/test_images\\158.jpg',
#  'photos/test_images\\1580.jpg',
#  'photos/test_images\\1581.jpg',
#  'photos/test_images\\1582.jpg',
#  'photos/test_images\\1583.jpg',
#  'photos/test_images\\1584.jpg',
#  'photos/test_images\\1585.jpg',
#  'photos/test_images\\1586.jpg',
#  'photos/test_images\\1587.jpg',
#  'photos/test_images\\1588.jpg',
#  'photos/test_images\\1589.jpg',
#  'photos/test_images\\159.jpg',
#  'photos/test_images\\1590.jpg',
#  'photos/test_images\\1591.jpg',
#  'photos/test_images\\1592.jpg',
#  'photos/test_images\\1593.jpg',
#  'photos/test_images\\1594.jpg',
#  'photos/test_images\\1595.jpg',
#  'photos/test_images\\1596.jpg',
#  'photos/test_images\\1597.jpg',
#  'photos/test_images\\1598.jpg',
#  'photos/test_images\\1599.jpg',
#  'photos/test_images\\16.jpg',
#  'photos/test_images\\160.jpg',
#  'photos/test_images\\1600.jpg',
#  'photos/test_images\\1601.jpg',
#  'photos/test_images\\1602.jpg',
#  'photos/test_images\\1603.jpg',
#  'photos/test_images\\1604.jpg',
#  'photos/test_images\\1605.jpg',
#  'photos/test_images\\1606.jpg',
#  'photos/test_images\\1607.jpg',
#  'photos/test_images\\1608.jpg',
#  'photos/test_images\\1609.jpg',
#  'photos/test_images\\161.jpg',
#  'photos/test_images\\1610.jpg',
#  'photos/test_images\\1611.jpg',
#  'photos/test_images\\1612.jpg',
#  'photos/test_images\\1613.jpg',
#  'photos/test_images\\1614.jpg',
#  'photos/test_images\\1615.jpg',
#  'photos/test_images\\1616.jpg',
#  'photos/test_images\\1617.jpg',
#  'photos/test_images\\1618.jpg',
#  'photos/test_images\\1619.jpg',
#  'photos/test_images\\162.jpg',
#  'photos/test_images\\1620.jpg',
#  'photos/test_images\\1621.jpg',
#  'photos/test_images\\1622.jpg',
#  'photos/test_images\\1623.jpg',
#  'photos/test_images\\1624.jpg',
#  'photos/test_images\\1625.jpg',
#  'photos/test_images\\1626.jpg',
#  'photos/test_images\\1627.jpg',
#  'photos/test_images\\1628.jpg',
#  'photos/test_images\\1629.jpg',
#  'photos/test_images\\163.jpg',
#  'photos/test_images\\1630.jpg',
#  'photos/test_images\\1631.jpg',
#  'photos/test_images\\1632.jpg',
#  'photos/test_images\\1633.jpg',
#  'photos/test_images\\1634.jpg',
#  'photos/test_images\\1635.jpg',
#  'photos/test_images\\1636.jpg',
#  'photos/test_images\\1637.jpg',
#  'photos/test_images\\1638.jpg',
#  'photos/test_images\\1639.jpg',
#  'photos/test_images\\164.jpg',
#  'photos/test_images\\1640.jpg',
#  'photos/test_images\\1641.jpg',
#  'photos/test_images\\1642.jpg',
#  'photos/test_images\\1643.jpg',
#  'photos/test_images\\1644.jpg',
#  'photos/test_images\\1645.jpg',
#  'photos/test_images\\1646.jpg',
#  'photos/test_images\\1647.jpg',
#  'photos/test_images\\1648.jpg',
#  'photos/test_images\\1649.jpg',
#  'photos/test_images\\165.jpg',
#  'photos/test_images\\1650.jpg',
#  'photos/test_images\\1651.jpg',
#  'photos/test_images\\1652.jpg',
#  'photos/test_images\\1653.jpg',
#  'photos/test_images\\1654.jpg',
#  'photos/test_images\\1655.jpg',
#  'photos/test_images\\1656.jpg',
#  'photos/test_images\\1657.jpg',
#  'photos/test_images\\1658.jpg',
#  'photos/test_images\\1659.jpg',
#  'photos/test_images\\166.jpg',
#  'photos/test_images\\1660.jpg',
#  'photos/test_images\\1661.jpg',
#  'photos/test_images\\1662.jpg',
#  'photos/test_images\\1663.jpg',
#  'photos/test_images\\1664.jpg',
#  'photos/test_images\\1665.jpg',
#  'photos/test_images\\1666.jpg',
#  'photos/test_images\\1667.jpg',
#  'photos/test_images\\1668.jpg',
#  'photos/test_images\\1669.jpg',
#  'photos/test_images\\167.jpg',
#  'photos/test_images\\1670.jpg',
#  'photos/test_images\\1671.jpg',
#  'photos/test_images\\1672.jpg',
#  'photos/test_images\\1673.jpg',
#  'photos/test_images\\1674.jpg',
#  'photos/test_images\\1675.jpg',
#  'photos/test_images\\1676.jpg',
#  'photos/test_images\\1677.jpg',
#  'photos/test_images\\1678.jpg',
#  'photos/test_images\\1679.jpg',
#  'photos/test_images\\168.jpg',
#  'photos/test_images\\1680.jpg',
#  'photos/test_images\\1681.jpg',
#  'photos/test_images\\1682.jpg',
#  'photos/test_images\\1683.jpg',
#  'photos/test_images\\1684.jpg',
#  'photos/test_images\\1685.jpg',
#  'photos/test_images\\1686.jpg',
#  'photos/test_images\\1687.jpg',
#  'photos/test_images\\1688.jpg',
#  'photos/test_images\\1689.jpg',
#  'photos/test_images\\169.jpg',
#  'photos/test_images\\1690.jpg',
#  'photos/test_images\\1691.jpg',
#  'photos/test_images\\1692.jpg',
#  'photos/test_images\\1693.jpg',
#  'photos/test_images\\1694.jpg',
#  'photos/test_images\\1695.jpg',
#  'photos/test_images\\1696.jpg',
#  'photos/test_images\\1697.jpg',
#  'photos/test_images\\1698.jpg',
#  'photos/test_images\\1699.jpg',
#  'photos/test_images\\17.jpg',
#  'photos/test_images\\170.jpg',
#  'photos/test_images\\1700.jpg',
#  'photos/test_images\\1701.jpg',
#  'photos/test_images\\1702.jpg',
#  'photos/test_images\\1703.jpg',
#  'photos/test_images\\1704.jpg',
#  'photos/test_images\\1705.jpg',
#  'photos/test_images\\1706.jpg',
#  'photos/test_images\\1707.jpg',
#  'photos/test_images\\1708.jpg',
#  'photos/test_images\\1709.jpg',
#  'photos/test_images\\171.jpg',
#  'photos/test_images\\1710.jpg',
#  'photos/test_images\\1711.jpg',
#  'photos/test_images\\1712.jpg',
#  'photos/test_images\\1713.jpg',
#  'photos/test_images\\1714.jpg',
#  'photos/test_images\\1715.jpg',
#  'photos/test_images\\1716.jpg',
#  'photos/test_images\\1717.jpg',
#  'photos/test_images\\1718.jpg',
#  'photos/test_images\\1719.jpg',
#  'photos/test_images\\172.jpg',
#  'photos/test_images\\1720.jpg',
#  'photos/test_images\\1721.jpg',
#  'photos/test_images\\1722.jpg',
#  'photos/test_images\\1723.jpg',
#  'photos/test_images\\1724.jpg',
#  'photos/test_images\\1725.jpg',
#  'photos/test_images\\1726.jpg',
#  'photos/test_images\\1727.jpg',
#  'photos/test_images\\1728.jpg',
#  'photos/test_images\\1729.jpg',
#  'photos/test_images\\173.jpg',
#  'photos/test_images\\1730.jpg',
#  'photos/test_images\\1731.jpg',
#  'photos/test_images\\1732.jpg',
#  'photos/test_images\\1733.jpg',
#  'photos/test_images\\1734.jpg',
#  'photos/test_images\\1735.jpg',
#  'photos/test_images\\1736.jpg',
#  'photos/test_images\\1737.jpg',
#  'photos/test_images\\1738.jpg',
#  'photos/test_images\\1739.jpg',
#  'photos/test_images\\174.jpg',
#  'photos/test_images\\1740.jpg',
#  'photos/test_images\\1741.jpg',
#  'photos/test_images\\1742.jpg',
#  'photos/test_images\\1743.jpg',
#  'photos/test_images\\1744.jpg',
#  'photos/test_images\\1745.jpg',
#  'photos/test_images\\1746.jpg',
#  'photos/test_images\\1747.jpg',
#  'photos/test_images\\1748.jpg',
#  'photos/test_images\\1749.jpg',
#  'photos/test_images\\175.jpg',
#  'photos/test_images\\1750.jpg',
#  'photos/test_images\\1751.jpg',
#  'photos/test_images\\1752.jpg',
#  'photos/test_images\\1753.jpg',
#  'photos/test_images\\1754.jpg',
#  'photos/test_images\\1755.jpg',
#  'photos/test_images\\1756.jpg',
#  'photos/test_images\\1757.jpg',
#  'photos/test_images\\1758.jpg',
#  'photos/test_images\\1759.jpg',
#  'photos/test_images\\176.jpg',
#  'photos/test_images\\1760.jpg',
#  'photos/test_images\\1761.jpg',
#  'photos/test_images\\1762.jpg',
#  'photos/test_images\\1763.jpg',
#  'photos/test_images\\1764.jpg',
#  'photos/test_images\\1765.jpg',
#  'photos/test_images\\1766.jpg',
#  'photos/test_images\\1767.jpg',
#  'photos/test_images\\1768.jpg',
#  'photos/test_images\\1769.jpg',
#  'photos/test_images\\177.jpg',
#  'photos/test_images\\1770.jpg',
#  'photos/test_images\\1771.jpg',
#  'photos/test_images\\1772.jpg',
#  'photos/test_images\\1773.jpg',
#  'photos/test_images\\1774.jpg',
#  'photos/test_images\\1775.jpg',
#  'photos/test_images\\1776.jpg',
#  'photos/test_images\\1777.jpg',
#  'photos/test_images\\1778.jpg',
#  'photos/test_images\\1779.jpg',
#  'photos/test_images\\178.jpg',
#  'photos/test_images\\1780.jpg',
#  'photos/test_images\\1781.jpg',
#  'photos/test_images\\1782.jpg',
#  'photos/test_images\\1783.jpg',
#  'photos/test_images\\1784.jpg',
#  'photos/test_images\\1785.jpg',
#  'photos/test_images\\1786.jpg',
#  'photos/test_images\\1787.jpg',
#  'photos/test_images\\1788.jpg',
#  'photos/test_images\\1789.jpg',
#  'photos/test_images\\179.jpg',
#  'photos/test_images\\1790.jpg',
#  'photos/test_images\\1791.jpg',
#  'photos/test_images\\1792.jpg',
#  'photos/test_images\\1793.jpg',
#  'photos/test_images\\1794.jpg',
#  'photos/test_images\\1795.jpg',
#  'photos/test_images\\1796.jpg',
#  'photos/test_images\\1797.jpg',
#  'photos/test_images\\1798.jpg',
#  'photos/test_images\\1799.jpg',
#  'photos/test_images\\18.jpg',
#  'photos/test_images\\180.jpg',
#  'photos/test_images\\1800.jpg',
#  'photos/test_images\\1801.jpg',
#  'photos/test_images\\1802.jpg',
#  'photos/test_images\\1803.jpg',
#  'photos/test_images\\1804.jpg',
#  'photos/test_images\\1805.jpg',
#  'photos/test_images\\1806.jpg',
#  'photos/test_images\\1807.jpg',
#  'photos/test_images\\1808.jpg',
#  'photos/test_images\\1809.jpg',
#  'photos/test_images\\181.jpg',
#  'photos/test_images\\1810.jpg',
#  'photos/test_images\\1811.jpg',
#  'photos/test_images\\1812.jpg',
#  'photos/test_images\\1813.jpg',
#  'photos/test_images\\1814.jpg',
#  'photos/test_images\\1815.jpg',
#  'photos/test_images\\1816.jpg',
#  'photos/test_images\\1817.jpg',
#  'photos/test_images\\1818.jpg',
#  'photos/test_images\\1819.jpg',
#  'photos/test_images\\182.jpg',
#  'photos/test_images\\1820.jpg',
#  'photos/test_images\\1821.jpg',
#  'photos/test_images\\1822.jpg',
#  'photos/test_images\\1823.jpg',
#  'photos/test_images\\1824.jpg',
#  'photos/test_images\\1825.jpg',
#  'photos/test_images\\1826.jpg',
#  'photos/test_images\\1827.jpg',
#  'photos/test_images\\1828.jpg',
#  'photos/test_images\\1829.jpg',
#  'photos/test_images\\183.jpg',
#  'photos/test_images\\1830.jpg',
#  'photos/test_images\\1831.jpg',
#  'photos/test_images\\1832.jpg',
#  'photos/test_images\\1833.jpg',
#  'photos/test_images\\1834.jpg',
#  'photos/test_images\\1835.jpg',
#  'photos/test_images\\1836.jpg',
#  'photos/test_images\\1837.jpg',
#  'photos/test_images\\1838.jpg',
#  'photos/test_images\\1839.jpg',
#  'photos/test_images\\184.jpg',
#  'photos/test_images\\1840.jpg',
#  'photos/test_images\\1841.jpg',
#  'photos/test_images\\1842.jpg',
#  'photos/test_images\\1843.jpg',
#  'photos/test_images\\1844.jpg',
#  'photos/test_images\\1845.jpg',
#  'photos/test_images\\1846.jpg',
#  'photos/test_images\\1847.jpg',
#  'photos/test_images\\1848.jpg',
#  'photos/test_images\\1849.jpg',
#  'photos/test_images\\185.jpg',
#  'photos/test_images\\1850.jpg',
#  'photos/test_images\\1851.jpg',
#  'photos/test_images\\1852.jpg',
#  'photos/test_images\\1853.jpg',
#  'photos/test_images\\1854.jpg',
#  'photos/test_images\\1855.jpg',
#  'photos/test_images\\1856.jpg',
#  'photos/test_images\\1857.jpg',
#  'photos/test_images\\1858.jpg',
#  'photos/test_images\\1859.jpg',
#  'photos/test_images\\186.jpg',
#  'photos/test_images\\1860.jpg',
#  'photos/test_images\\1861.jpg',
#  'photos/test_images\\1862.jpg',
#  'photos/test_images\\1863.jpg',
#  'photos/test_images\\1864.jpg',
#  'photos/test_images\\1865.jpg',
#  'photos/test_images\\1866.jpg',
#  'photos/test_images\\1867.jpg',
#  'photos/test_images\\1868.jpg',
#  'photos/test_images\\1869.jpg',
#  'photos/test_images\\187.jpg',
#  'photos/test_images\\1870.jpg',
#  'photos/test_images\\1871.jpg',
#  'photos/test_images\\1872.jpg',
#  'photos/test_images\\1873.jpg',
#  'photos/test_images\\1874.jpg',
#  'photos/test_images\\1875.jpg',
#  'photos/test_images\\1876.jpg',
#  'photos/test_images\\1877.jpg',
#  'photos/test_images\\1878.jpg',
#  'photos/test_images\\1879.jpg',
#  'photos/test_images\\188.jpg',
#  'photos/test_images\\1880.jpg',
#  'photos/test_images\\1881.jpg',
#  'photos/test_images\\1882.jpg',
#  'photos/test_images\\1883.jpg',
#  'photos/test_images\\1884.jpg',
#  'photos/test_images\\1885.jpg',
#  'photos/test_images\\1886.jpg',
#  'photos/test_images\\189.jpg',
#  'photos/test_images\\19.jpg',
#  'photos/test_images\\190.jpg',
#  'photos/test_images\\191.jpg',
#  'photos/test_images\\192.jpg',
#  'photos/test_images\\193.jpg',
#  'photos/test_images\\194.jpg',
#  'photos/test_images\\195.jpg',
#  'photos/test_images\\196.jpg',
#  'photos/test_images\\197.jpg',
#  'photos/test_images\\198.jpg',
#  'photos/test_images\\199.jpg',
#  'photos/test_images\\2.jpg',
#  'photos/test_images\\20.jpg',
#  ...]

# %%
labels_to_names = {0: 'yaya', 1: 'arac'}
# !python keras_retinanet/bin/convert_model.py ./snapshots/resnet50_csv_10.h5 ./snapshots/resnet50_csv_10_infer.h5
model = models.load_model("./snapshots/resnet50_csv_14_infer.h5", backbone_name='resnet50')
# Out:
# c:\users\mbura\appdata\local\programs\python\python36\lib\site-packages\keras\engine\saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '

# %%
resnet50_images=[]
for i in tqdm(val_sample):
    image = read_image_bgr(i)
    sha=image.shape
    image = preprocess_image(image)
    image, scale = resize_image(image,max_side=3000)
    boxes, scores, labels = model.predict_on_batch(np.expand_dims(image, axis=0))
    boxes /= scale
    for box, score, label in zip(boxes[0], scores[0], labels[0]):
        if score < 0.5:
            break
        b = box.astype(int)
        label_=labels_to_names[label]
        resnet50_images.append([i,b[0],b[1],b[2],b[3],label_,score])
resnet50_images=pd.DataFrame(resnet50_images,columns=["path","x1","y1","x2","y2","label","score"])
resnet50_images.to_csv("resnet50_preds_scaled.csv",index=False)
# Out:
#   0%|                                                                                         | 0/1886 [00:00<?, ?it/s]
#   0%|                                                                                 | 1/1886 [00:00<26:55,  1.17it/s]
#   0%|                                                                                 | 2/1886 [00:01<22:00,  1.43it/s]
#   0%|▏                                                                                | 3/1886 [00:01<18:45,  1.67it/s]
#   0%|▏                                                                                | 4/1886 [00:01<16:19,  1.92it/s]
#   0%|▏                                                                                | 5/1886 [00:02<14:40,  2.14it/s]
#   0%|▎                                                                                | 6/1886 [00:02<13:25,  2.33it/s]
#   0%|▎                                                                                | 7/1886 [00:02<12:34,  2.49it/s]
#   0%|▎                                                                                | 8/1886 [00:03<12:01,  2.60it/s]
#   0%|▍                                                                                | 9/1886 [00:03<11:34,  2.70it/s]
#   1%|▍                                                                               | 10/1886 [00:03<11:14,  2.78it/s]
#   1%|▍                                                                               | 11/1886 [00:04<10:59,  2.84it/s]
#   1%|▌                                                                               | 12/1886 [00:04<10:51,  2.88it/s]
#   1%|▌                                                                               | 13/1886 [00:04<10:46,  2.90it/s]
#   1%|▌                                                                               | 14/1886 [00:05<10:38,  2.93it/s]
#   1%|▋                                                                               | 15/1886 [00:05<10:36,  2.94it/s]
#   1%|▋                                                                               | 16/1886 [00:05<10:34,  2.95it/s]
#   1%|▋                                                                               | 17/1886 [00:06<10:33,  2.95it/s]
#   1%|▊                                                                               | 18/1886 [00:06<10:29,  2.97it/s]
#   1%|▊                                                                               | 19/1886 [00:06<10:26,  2.98it/s]
#   1%|▊                                                                               | 20/1886 [00:07<10:27,  2.97it/s]
#   1%|▉                                                                               | 21/1886 [00:07<10:26,  2.98it/s]
/s]
#  99%|████████████████████████████████████████████████████████████████████████████▉ | 1861/1886 [10:53<00:08,  2.84it/s]
#  99%|█████████████████████████████████████████████████████████████████████████████ | 1862/1886 [10:53<00:08,  2.83it/s]
#  99%|█████████████████████████████████████████████████████████████████████████████ | 1863/1886 [10:53<00:08,  2.83it/s]
#  99%|█████████████████████████████████████████████████████████████████████████████ | 1864/1886 [10:54<00:07,  2.83it/s]
#  99%|█████████████████████████████████████████████████████████████████████████████▏| 1865/1886 [10:54<00:07,  2.83it/s]
#  99%|█████████████████████████████████████████████████████████████████████████████▏| 1866/1886 [10:55<00:07,  2.81it/s]
#  99%|█████████████████████████████████████████████████████████████████████████████▏| 1867/1886 [10:55<00:06,  2.82it/s]
#  99%|█████████████████████████████████████████████████████████████████████████████▎| 1868/1886 [10:55<00:06,  2.82it/s]
#  99%|█████████████████████████████████████████████████████████████████████████████▎| 1869/1886 [10:56<00:06,  2.83it/s]
#  99%|█████████████████████████████████████████████████████████████████████████████▎| 1870/1886 [10:56<00:05,  2.82it/s]
#  99%|█████████████████████████████████████████████████████████████████████████████▍| 1871/1886 [10:56<00:05,  2.81it/s]
#  99%|█████████████████████████████████████████████████████████████████████████████▍| 1872/1886 [10:57<00:04,  2.82it/s]
#  99%|█████████████████████████████████████████████████████████████████████████████▍| 1873/1886 [10:57<00:04,  2.82it/s]
#  99%|█████████████████████████████████████████████████████████████████████████████▌| 1874/1886 [10:57<00:04,  2.82it/s]
#  99%|█████████████████████████████████████████████████████████████████████████████▌| 1875/1886 [10:58<00:03,  2.82it/s]
#  99%|█████████████████████████████████████████████████████████████████████████████▌| 1876/1886 [10:58<00:03,  2.84it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████▋| 1877/1886 [10:58<00:03,  2.84it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████▋| 1878/1886 [10:59<00:02,  2.86it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████▋| 1879/1886 [10:59<00:02,  2.86it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████▊| 1880/1886 [10:59<00:02,  2.85it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████▊| 1881/1886 [11:00<00:01,  2.85it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████▊| 1882/1886 [11:00<00:01,  2.84it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████▉| 1883/1886 [11:01<00:01,  2.80it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████▉| 1884/1886 [11:01<00:00,  2.81it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████▉| 1885/1886 [11:01<00:00,  2.83it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████| 1886/1886 [11:02<00:00,  2.84it/s]

# %%
# # tbd
# # os.mkdir("nigg")
# for path in resnet50_images["path"].value_counts().index:
#     image=cv2.imread(path)
#     unq_df=resnet50_images.loc[resnet50_images.path==path]
#     for bb in unq_df.values:
#         cv2.rectangle(image,(bb[1],bb[2]),(bb[3],bb[4]),(255,0,0),3)
#     cv2.imwrite("nigg/"+path.split("/")[-1].split("\\")[1],image)

# %%
# val_sample=val_set
# labels_to_names = {0: 'yaya', 1: 'arac'}
# !python keras_retinanet/bin/convert_model.py ./snapshots/resnet152_csv_07.h5 ./snapshots/infer_model.h5
# model = models.load_model("./snapshots/infer_model.h5", backbone_name='resnet152')
# resnet152_images=[]
# for i in tqdm(val_sample):# load image
#     image = read_image_bgr(i)
#     sha=image.shape
#     image = preprocess_image(image)
#     image, scale = resize_image(image,max_side=3000)
#     boxes, scores, labels = model.predict_on_batch(np.expand_dims(image, axis=0))
#     boxes /= scale
#     for box, score, label in zip(boxes[0], scores[0], labels[0]):
#         if score < 0.5:
#             break
#         b = box.astype(int)       
#         label_=labels_to_names[label]
#         resnet152_images.append([i,b[0],b[1],b[2],b[3],label_,score])
# resnet152_images=pd.DataFrame(resnet152_images,columns=["path","x1","y1","x2","y2","label","score"])
# resnet152_images.to_csv("resnet152_preds_scaled.csv",index=False)

# !python keras_retinanet/bin/convert_model.py ./snapshots/resnet101_csv_06.h5 ./snapshots/infer_model.h5
# model = models.load_model("./snapshots/infer_model.h5", backbone_name='resnet101')
# resnet101_images=[]
# for i in tqdm(val_sample):# load image
#     image = read_image_bgr(i)
#     sha=image.shape
#     image = preprocess_image(image)
#     image, scale = resize_image(image,max_side=3000)
#     boxes, scores, labels = model.predict_on_batch(np.expand_dims(image, axis=0))
#     boxes /= scale
#     for box, score, label in zip(boxes[0], scores[0], labels[0]):
#         if score < 0.5:
#             break
#         b = box.astype(int)       
#         label_=labels_to_names[label]
#         resnet101_images.append([i,b[0],b[1],b[2],b[3],label_,score])
# resnet101_images=pd.DataFrame(resnet101_images,columns=["path","x1","y1","x2","y2","label","score"])
# resnet101_images.to_csv("resnet101_preds_scaled.csv",index=False)

# !python keras_retinanet/bin/convert_model.py ./snapshots/resnet50_csv_12.h5 ./snapshots/infer_model.h5
# model = models.load_model("./snapshots/infer_model.h5", backbone_name='resnet50')
# resnet50_images=[]
# for i in tqdm(val_sample):# load image
#     image = read_image_bgr(i)
#     sha=image.shape
#     image = preprocess_image(image)
#     image, scale = resize_image(image,max_side=3000)
#     boxes, scores, labels = model.predict_on_batch(np.expand_dims(image, axis=0))
#     boxes /= scale
#     for box, score, label in zip(boxes[0], scores[0], labels[0]):
#         if score < 0.5:
#             break
#         b = box.astype(int)       
#         label_=labels_to_names[label]
#         resnet50_images.append([i,b[0],b[1],b[2],b[3],label_,score])
# resnet50_images=pd.DataFrame(resnet50_images,columns=["path","x1","y1","x2","y2","label","score"])
# resnet50_images.to_csv("resnet50_preds_scaled.csv",index=False)

# !python keras_retinanet/bin/convert_model.py ./snapshots/vgg19_csv_09.h5 ./snapshots/infer_model.h5
# model = models.load_model("./snapshots/infer_model.h5", backbone_name='vgg19')
# vgg_images=[]
# for i in tqdm(val_sample):# load image
#     image = read_image_bgr(i)
#     sha=image.shape
#     image = preprocess_image(image)
#     image, scale = resize_image(image,max_side=3000)
#     boxes, scores, labels = model.predict_on_batch(np.expand_dims(image, axis=0))
#     boxes /= scale
#     for box, score, label in zip(boxes[0], scores[0], labels[0]):
#         if score < 0.5:
#             break
#         b = box.astype(int)
#         label_=labels_to_names[label]
#         vgg_images.append([i,b[0],b[1],b[2],b[3],label_,score])
# vgg_images=pd.DataFrame(vgg_images,columns=["path","x1","y1","x2","y2","label","score"])
# vgg_images.to_csv("vgg_preds_scaled.csv",index=False)

# %% [markdown]
# ## Load RetinaNet model

# %%
# !python keras_retinanet/bin/convert_model.py ./snapshots/resnet50_csv_12.h5 ./snapshots/infer_model.h5
model = models.load_model("./snapshots/infer_model.h5", backbone_name='resnet50')
labels_to_names = {0: 'yaya', 1: 'arac'}

# %%
os.listdir()

# %% [markdown]
# ## Run detection on example

# %%
val_sample=np.random.choice(val_set,1)
image = read_image_bgr(val_sample[0])
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(20, 30))
plt.imshow(image)

# %%
# resnet50_csv_01
for i in val_sample:# load image
    image = read_image_bgr(i)
    sha=image.shape
    # image=cv2.resize(image,(int(sha[1]*1.25),int(sha[0]*1.25)))
    draw = image.copy()
    draw = cv2.cvtColor(draw, cv2.COLOR_BGR2RGB)
    image = preprocess_image(image)
    image, scale = resize_image(image)
    start = time.time()
    boxes, scores, labels = model.predict_on_batch(np.expand_dims(image, axis=0))
    print("processing time: ", time.time() - start)
    print(i)
    boxes /= scale

    for box, score, label in zip(boxes[0], scores[0], labels[0]):
        # scores are sorted so we can break
        if score < 0.5:
            break
        color = label_color(label)

        b = box.astype(int)
        draw_box(draw, b, color=color)
        
        caption = "{} {:.3f}".format(labels_to_names[label], score)
        draw_caption(draw, b, caption)
    
    cv2.imwrite("a.jpg",draw)
    plt.figure(figsize=(20,20))
    plt.axis('off')
    plt.imshow(draw)
    plt.show()
    plt.pause(0.01)

# %%
os.getcwd()

# %% [markdown]
# ## migga

# %%
# train_csv=pd.read_csv("train.csv",header=None)
# train_csv.head()

# %%
# val_set=np.random.choice(train_csv[0].value_counts().index,100)
# for path in val_set:
#     image=cv2.imread(path)
#     image=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
#     unq_df=train_csv.loc[train_csv[0]==path]
#     for bbs in unq_df.values[:,1:]:
#         cv2.rectangle(image,(bbs[0],bbs[1]),(bbs[2],bbs[3]),(255,0,0),3)
#         cv2.putText(image,bbs[-1],(bbs[0],bbs[1]),cv2.FONT_HERSHEY_DUPLEX,2,(0,255,0))
#     plt.figure(figsize=(16,10))
#     plt.imshow(image)
#     plt.pause(0.001)
