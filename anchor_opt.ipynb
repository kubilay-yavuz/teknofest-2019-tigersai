# %%
# !pip install -q keras
# !pip install -q pandas
# !pip install -q numpy
# !pip install -q tensorflow
# !pip install -U -q PyDrive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import os
import glob
import pandas as pd
import numpy as np
import json
import cv2
from tqdm import tqdm

# %%
# !git clone https://github.com/martinzlocha/anchor-optimization/
os.chdir("anchor-optimization/")
# !pip install .
# !python setup.py build_ext --inplace
# Out:
# Cloning into 'anchor-optimization'...
# remote: Enumerating objects: 43, done.
# remote: Counting objects: 100% (43/43), done.
# remote: Compressing objects: 100% (37/37), done.
# remote: Total 43 (delta 21), reused 16 (delta 5), pack-reused 0
# Unpacking objects: 100% (43/43), done.
# Processing /content/anchor-optimization
# ...
#      |████████████████████████████████| 61kB 5.2MB/s
# ...
#   Created wheel for anchor-optimization: filename=anchor_optimization-0.0.1-cp36-cp36m-linux_x86_64.whl size=77460 sha256=66bdf1d30a38a961d50ee506cd8e06dec3a6c7c431ebe7c562ddd6661da214de
#   Stored in directory: /root/.cache/pip/wheels/52/cb/a7/aa0c417c0cb603e0a8bdb2887ffff23cf50a689d2113eb267e
# ...
#   Created wheel for keras-retinanet: filename=keras_retinanet-0.5.1-cp36-cp36m-linux_x86_64.whl size=156796 sha256=f99adc02babccdc420e588d901564b0a48fddf6caeb2031d2bbd07c93d20fba6
#   Stored in directory: /root/.cache/pip/wheels/d9/a5/98/87f8ed08913b184bb625dde1c1277a4dfe969c77b377abde69
# ...

# %%
# os.chdir("drive/My Drive/colab_datas/teknofest/anchor-optimization")
csv=pd.read_csv("/content/drive/My Drive/colab_datas/teknofest/keras-retinanet/t3_all_data.csv",header=None)
csv[0]=csv[0].apply(lambda x:"/content/drive/My Drive/colab_datas/teknofest/keras-retinanet/"+x)
csv.to_csv("t3_all_data.csv",index=False,header=None)

# %%
# !pip install keras_retinanet

# %%
# !python optimize_anchors.py --scales 3 --ratios 3 --no-resize t3_all_data.csv
# Out:
# Using TensorFlow backend.
# Loading object dimensions.
# Optimising anchors.
# Current best anchor configuration
# Ratios: [0.836, 1.0, 1.196]
# Scales: [0.498, 1.33, 1.872]
# Number of labels that don't have any matching anchor: 2122
#
# Current best anchor configuration
# Ratios: [0.63, 1.0, 1.586]
# Scales: [0.741, 1.605, 1.654]
# Number of labels that don't have any matching anchor: 1564
#
# Current best anchor configuration
# Ratios: [0.325, 1.0, 3.079]
# Scales: [0.626, 1.743, 1.852]
# Number of labels that don't have any matching anchor: 484
#
# Current best anchor configuration
# Ratios: [0.541, 1.0, 1.847]
# Scales: [0.693, 1.523, 1.784]
# Number of labels that don't have any matching anchor: 1095
#
# Current best anchor configuration
# Ratios: [0.597, 1.0, 1.675]
# Scales: [0.549, 0.935, 1.221]
# Number of labels that don't have any matching anchor: 949
#
# Current best anchor configuration
# Ratios: [0.456, 1.0, 2.194]
# Scales: [0.454, 0.832, 1.13]
# ...

# %%
# Final best anchor configuration
# Ratios: [0.491, 1.0, 2.037]
# Scales: [0.4, 0.504, 0.65]
# Number of labels that don't have any matching anchor: 266


# Current best anchor configuration
# Ratios: [0.313, 0.575, 1.0, 1.738, 3.2]
# Scales: [0.401, 0.432, 0.501, 0.607, 0.751]
# Number of labels that don't have any matching anchor: 19
