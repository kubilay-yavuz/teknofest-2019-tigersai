# %%
# !pip install -q keras
# !pip install -q pandas
# !pip install -q numpy
# !pip install -q tensorflow
# !pip install -U -q PyDrive

from google.colab import drive
drive.mount('/content/drive')
# Out:
#      |████████████████████████████████| 993kB 3.5MB/s
# ...
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import os
import glob
import pandas as pd
import numpy as np
import json
import cv2
from tqdm import tqdm

# %%
os.chdir("drive/My Drive/colab_datas/teknofest/darknet")

# %%
# !git clone https://github.com/AlexeyAB/darknet
# os.chdir("darknet")

# %%
new_path="build/darknet/x64/data/obj/"
os.listdir(new_path)[:10]
# Out:
# ['9999982_00000_d_0000032.txt',
#  '9999982_00000_d_0000032.jpg',
#  '9999956_00000_d_0000018.txt',
#  '9999956_00000_d_0000018.jpg',
#  '9999960_00000_d_0000148.txt',
#  '9999960_00000_d_0000148.jpg',
#  '9999985_00000_d_0000064.txt',
#  '9999985_00000_d_0000064.jpg',
#  'coupa_video2_560.txt',
#  'coupa_video2_560.jpg']

# %%
#all_df=pd.read_csv("/content/all_df.csv",header=None)
#all_df=all_df.loc[all_df[5]=="yaya"]

# %%
#all_df.head()
# Out:
#                                                       0     1  ...   4     5
# 3757  photos/t3/gonderilecek_veriler/B160519_V1_K1/f...  1076  ...  66  yaya
# 3758  photos/t3/gonderilecek_veriler/B160519_V1_K1/f...  1074  ...  78  yaya
# 3759  photos/t3/gonderilecek_veriler/B160519_V1_K1/f...  1086  ...  64  yaya
# 3760  photos/t3/gonderilecek_veriler/B160519_V1_K1/f...  1072  ...  88  yaya
# 3761  photos/t3/gonderilecek_veriler/B160519_V1_K1/f...  1083  ...  67  yaya
#
# [5 rows x 6 columns]

# %%
#bb_widths=all_df[3]-all_df[1]
#bb_heights=all_df[4]-all_df[2]
#all_df[1]=(all_df[3]+all_df[1])//2
#all_df[2]=(all_df[4]+all_df[2])//2
#all_df[3]=bb_widths
#all_df[4]=bb_heights
#all_df[0]="/content/drive/My Drive/colab_datas/teknofest/keras-retinanet/"+all_df[0]
#all_df.head()
# Out:
#                                                       0     1   2   3   4     5
# 3757  /content/drive/My Drive/colab_datas/teknofest/...  1091  38  31  56  yaya
# 3758  /content/drive/My Drive/colab_datas/teknofest/...  1089  49  31  57  yaya
# 3759  /content/drive/My Drive/colab_datas/teknofest/...  1096  36  20  55  yaya
# 3760  /content/drive/My Drive/colab_datas/teknofest/...  1084  59  24  58  yaya
# 3761  /content/drive/My Drive/colab_datas/teknofest/...  1091  43  16  48  yaya

# %%
#image_paths=all_df[0].value_counts().index
#
#for image_path in tqdm(image_paths):
#    img=cv2.imread(image_path)
#    width,height=img.shape[0],img.shape[1]
#    unq_df=all_df.loc[all_df[0]==image_path]
#    unq_df[1]=unq_df[1]/width
#    unq_df[2]=unq_df[2]/height
#    unq_df[3]=unq_df[3]/width
#    unq_df[4]=unq_df[4]/height
#    unq_df=unq_df.values[:,:5]
#    unq_df[:,0]=0
#    text_path=image_path.split("/")[-1].split(".")[0]+".txt"
#    np.savetxt(new_path+text_path,unq_df,fmt='%.6f')
#    cv2.imwrite(new_path+image_path.split("/")[-1],img)

# %%
os.getcwd()
# Out:
# '/content/drive/My Drive/colab_datas/teknofest/darknet'

# %%
train=["data/obj/"+i for i in os.listdir(new_path) if not i.endswith(".txt")]
test=train[6000:]
train=train[:6000]

# %%
np.savetxt("build/darknet/x64/data/train.txt",np.array(train),fmt="%s")
np.savetxt("build/darknet/x64/data/test.txt",np.array(test),fmt="%s")

# %%
# !wget -P build/darknet/x64 https://pjreddie.com/media/files/darknet53.conv.74
# Out:
# --2019-08-17 19:30:33--  https://pjreddie.com/media/files/darknet53.conv.74
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162482580 (155M) [application/octet-stream]
# Saving to: ‘build/darknet/x64/darknet53.conv.74’
#
# darknet53.conv.74   100%[===================>] 154.96M  46.8MB/s    in 3.5s
#
# 2019-08-17 19:30:37 (43.7 MB/s) - ‘build/darknet/x64/darknet53.conv.74’ saved [162482580/162482580]

# %%
os.chdir("build/darknet/x64/")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-46-ae914723e7b8> in <module>()
# ----> 1 os.chdir("build/darknet/x64/")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'build/darknet/x64/'

# %%
os.chdir("../")
os.chdir("../")
os.chdir("../")
os.getcwd()
# Out:
# '/content/drive/My Drive/colab_datas/teknofest/darknet'

# %%
# !make
# Out:
# chmod +x *.sh

# %%
# !./darknet detector train data/pedes.data yolo-pedes.cfg darknet53.conv.74
# Out:
# yolo-pedes
#    layer   filters  size/strd(dil)      input                output
#    0 conv     18       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  18 0.168 BF
#    1 conv     18       3 x 3/ 2    416 x 416 x  18 ->  208 x 208 x  18 0.252 BF
#    2 conv     18       1 x 1/ 1    208 x 208 x  18 ->  208 x 208 x  18 0.028 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  18 ->  208 x 208 x  64 0.897 BF
#    4 Shortcut Layer: 1
#  w = 208, w2 = 208, h = 208, h2 = 208, c = 64, c2 = 18
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#    7 ^C

# %%
# Out:
# mkdir -p obj
# mkdir -p backup
# mkdir -p results
# chmod +x *.sh
# g++ -std=c++11 -Iinclude/ -I3rdparty/stb/include -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -c ./src/image_opencv.cpp -o obj/image_opencv.o
# g++ -std=c++11 -Iinclude/ -I3rdparty/stb/include -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -c ./src/http_stream.cpp -o obj/http_stream.o
# ./src/http_stream.cpp: In member function ‘bool JSON_sender::write(const char*)’:
# ./src/http_stream.cpp:228:21: warning: unused variable ‘n’ [-Wunused-variable]
#                  int n = _write(client, outputbuf, outlen);
#                      ^
# gcc -Iinclude/ -I3rdparty/stb/include -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -c ./src/gemm.c -o obj/gemm.o
# ./src/gemm.c: In function ‘convolution_2d’:
# ./src/gemm.c:2037:15: warning: unused variable ‘out_w’ [-Wunused-variable]
# ...
